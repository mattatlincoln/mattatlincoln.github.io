# %%
import PIL
from IPython.display import display, Image
%
# Out:
# UsageError: Line magic function `%display` not found.

# %%
PIL.PILLOW_VERSION
# Out:
# '5.4.1'

# %%
from PIL import Image, ImageDraw
from IPython.display import Image as dispImage

img = Image.open('architecture.jpg')
img = img.convert('RGB')
pixelMap = img.load()
img.save('tmp.png')
dispImage(filename='tmp.png')

# %%
from IPython.display import Image
Image(filename='architecture.jpg')

# %%
img = Image.open('architecture.jpg')
img = img.convert('RGB')
pixelMap = img.load()

img.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-957516ec7fa8> in <module>
# ----> 1 img = Image.open('architecture.jpg')
#       2 img = img.convert('RGB')
#       3 pixelMap = img.load()
#       4
#       5 img.show()
#
# AttributeError: type object 'Image' has no attribute 'open'

# %%
import mobilechelonian
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-19-970ae60f62bf> in <module>
# ----> 1 import mobilechelonian
#
# ModuleNotFoundError: No module named 'mobilechelonian'
